# %%
from sqlalchemy import create_engine
import os
import pandas as pd

# %%
path=os.getcwd()[:-4]+'db.sqlite3'

# %%
engine = create_engine('sqlite:///'+path)
engine.connect()

# %%
pd.read_sql('select * from news_news',engine)
# Out:
#     id                                              title  \
# 0    1   FPL team news: Klopp on Salah's fitness for GW24
# 1    2  Environmental Activists Glue Themselves to Roa...
# 2    3  How to Set Parental Controls on Your Smart Spe...
# 3    4  LaLiga Experience celebrates the 101st anniver...
# 4    5  Cadiz CF part company with manager Alvaro Cervera
# 5    6  The 22 Best 'Close-Up Photographer of the Year...
# 6    7  React Best Practices – Tips for Writing Better...
# 7    8  Laguardia takes on the Roulette Challenge on L...
# 8    9  Can You Really Tell the Difference Between 4K ...
# 9   10  Neo-Nazis Mostly Thrilled Joe Rogan Called The...
# 10  11  LaLiga clubs receive the first payment from Bo...
# 11  12   Switzerland's Beat Feuz wins men's Olympic do...
# 12  13          How much do you know about Ferran Torres?
# 13  14   Leaders Remo beat 3SC, maintain 11-game unbea...
# 14  15            How to Build Your Own Heroku with Dokku
# ...
